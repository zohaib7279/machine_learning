# %%
import numpy as np

# %%
np.array(4)
# Out:
# array(4)

# %%
arr = np.array([1, 2, 3, 4, 5])
print(arr)
# Out:
# [1 2 3 4 5]

# %%
arr.ndim
# Out:
# 1

# %%
mat = np.array([[1,2,3],[4,5,6]])

# %%
mat
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
mat.ndim
# Out:
# 2

# %%
c = np.array([
    [
        [1, 2],
        [3, 4]
    ],
    [
        [5, 6],
        [7, 8]
    ]
])

print(c.shape)
# Out:
# (2, 2, 2)

# %%
c.ndim
# Out:
# 3
